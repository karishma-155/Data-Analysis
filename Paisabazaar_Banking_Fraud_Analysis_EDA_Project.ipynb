# %% [markdown]
# <a href="https://colab.research.google.com/github/karishma-155/Data-Analysis/blob/main/Paisabazaar_Banking_Fraud_Analysis_EDA_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Paisabazar Banking Fraud Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# In today’s rapidly growing digital banking ecosystem, financial fraud has become a major challenge for online financial platforms such as Paisabazar. With millions of users performing credit, loan, and banking-related transactions every day, identifying fraudulent activities in real time is critical to minimize financial losses and maintain customer trust.
#
# This project focuses on analyzing a banking transaction dataset from Paisabazar to uncover fraud patterns, risky behaviors, and key indicators of suspicious activity. The dataset consists of structured CSV files containing both categorical and numerical variables, including customer information, transaction amount, account type, device details, location data, transaction frequency, and fraud labels.

# %% [markdown]
# ##Purpose of the Project
#
# The primary objective of this analysis is to leverage data-driven insights to improve fraud detection and prevention strategies. The project aims to support:
#
# - Risk management and fraud prevention
#
# - Secure digital banking operations
#
# - Customer trust and platform reliability
#
# - Data-driven decision-making for financial institutions

# %% [markdown]
# ## Key Analytical Objectives
# 1. Fraud Pattern Identification
#
# Analyze the distribution of fraudulent vs. non-fraudulent transactions
#
# 2. Customer Behavior Analysis
#
# Understand behavioral patterns of high-risk customers
#
# Examine the relationship between transaction frequency, transaction value, and fraud occurrence
#
# 3. Transaction-Level Insights
#
# Detect time-based trends and fraud spikes across different periods
#
# Analyze the impact of device type, location, and account category on fraud
#
# 4. Risk Factor Analysis
#
# Identify the most influential features contributing to fraud
#
# Compare low-value and high-value transactions in fraud cases

# %% [markdown]
# ##Why This Matters
#
# Insights derived from this analysis can help:
#
# Banks and financial institutions strengthen fraud detection systems
#
# Data analysts and data scientists build accurate fraud prediction models
#
# Compliance and risk teams reduce financial losses and regulatory risks
#
# Customers experience become safer and it can be more secure digital banking services.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**
# Paisabazaar helps customers apply for loans and credit cards by evaluating their creditworthiness. Credit scores are an important factor used by financial institutions to decide whether a customer is eligible for credit. However, understanding which customer behaviors and financial factors most strongly affect credit scores can be challenging.
#
# This project aims to analyze customer credit data to answer the following key questions:
#
# Does a higher annual income lead to a higher credit score?
#
# - Does a higher annual income lead to a higher credit score?
# - Does the credit utilization ratio have a stronger impact on credit scores than the number of loans taken?
# - Is having a higher number of credit cards linked to better credit scores when credit utilization is well managed?
# - Is there a negative relationship between the number of delayed payments and credit scores?
#
# To address these questions, the project analyzes customer information such as income, age, number of loans, credit card usage, outstanding debt, payment behavior, and credit history. The goal is to identify the most important factors influencing credit scores and to build a model that can classify customers into Poor, Standard, or Good credit score categories.
#
# The results of this analysis will help Paisabazaar improve credit risk assessment, reduce loan default risks, and provide more accurate and personalized financial recommendations to customers.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# - The main business objective of this project is to help Paisabazaar improve the way it evaluates customer creditworthiness using data-driven insights. By analyzing customer financial and credit behavior data, the project aims to identify the key factors that influence credit scores, such as income, credit utilization, number of loans, delayed payments, and overall payment behavior. Understanding these factors will allow Paisabazaar to assess credit risk more accurately and consistently.
#
# - The project also focuses on building a reliable model that can classify customers into Poor, Standard, and Good credit score categories. This will support faster and more accurate loan approval decisions while reducing the risk of loan defaults. In addition, the insights gained from this analysis can be used to offer personalized financial recommendations to customers, such as advice on managing credit card usage or improving payment habits. Overall, this project aims to enhance decision-making, improve customer trust, and support safer and more profitable lending for Paisabazaar and its partner financial institutions.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
from numpy import loadtxt
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rcParams
import warnings
warnings.filterwarnings('ignore')
# Setting Style and fig
sns.set_style("darkgrid")
plt.rcParams['figure.figsize'] = (10,5)
pd.set_option('display.max_colwidth', 200)

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df = pd.read_csv("/content/dataset.csv")
print(df)
# Out:
#           ID  Customer_ID  Month            Name   Age          SSN  \
# 0       5634         3392      1   Aaron Maashoh  23.0  821000265.0
# 1       5635         3392      2   Aaron Maashoh  23.0  821000265.0
# 2       5636         3392      3   Aaron Maashoh  23.0  821000265.0
# 3       5637         3392      4   Aaron Maashoh  23.0  821000265.0
# 4       5638         3392      5   Aaron Maashoh  23.0  821000265.0
# ...      ...          ...    ...             ...   ...          ...
# 10283  21057        10476      4  Michael Roddyt  33.0  901014028.0
# 10284  21058        10476      5  Michael Roddyt  33.0  901014028.0
# 10285  21059        10476      6  Michael Roddyt  33.0  901014028.0
# 10286  21060        10476      7  Michael Roddyt  33.0  901014028.0
# 10287  21061        10476      8  Michael Roddyt  33.0  901014028.0
#
#       Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0      Scientist       19114.12            1824.843333                3.0
# ...

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
df.tail()
# Out:
#           ID  Customer_ID  Month            Name   Age          SSN  \
# 10283  21057        10476      4  Michael Roddyt  33.0  901014028.0
# 10284  21058        10476      5  Michael Roddyt  33.0  901014028.0
# 10285  21059        10476      6  Michael Roddyt  33.0  901014028.0
# 10286  21060        10476      7  Michael Roddyt  33.0  901014028.0
# 10287  21061        10476      8  Michael Roddyt  33.0  901014028.0
#
#       Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 10283   Musician       48121.32                4253.11                6.0
# 10284   Musician       48121.32                4253.11                6.0
# 10285   Musician       48121.32                4253.11                6.0
# 10286   Musician       48121.32                4253.11                6.0
# 10287   Musician       48121.32                4253.11                6.0
#
#        ...  Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (10288, 28)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10288 entries, 0 to 10287
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        10288 non-null  int64
#  1   Customer_ID               10288 non-null  int64
#  2   Month                     10288 non-null  int64
#  3   Name                      10288 non-null  object
#  4   Age                       10288 non-null  float64
#  5   SSN                       10288 non-null  float64
#  6   Occupation                10288 non-null  object
#  7   Annual_Income             10288 non-null  float64
#  8   Monthly_Inhand_Salary     10288 non-null  float64
#  9   Num_Bank_Accounts         10288 non-null  float64
#  10  Num_Credit_Card           10288 non-null  float64
#  11  Interest_Rate             10288 non-null  float64
#  12  Num_of_Loan               10288 non-null  float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# ID                          0
# Customer_ID                 0
# Month                       0
# Name                        0
# Age                         0
# SSN                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            1
# Credit_Utilization_Ratio    1
# Credit_History_Age          1
# Payment_of_Min_Amount       1
# Total_EMI_per_month         1
# Amount_invested_monthly     1
# Payment_Behaviour           1
# Monthly_Balance             1
# Credit_Score                1
# dtype: int64

# %%
# Visualizing the missing values
sns.heatmap(df.isnull(), cbar=False)
plt.xlabel("Name of Columns", size=8, weight="bold")
plt.ylabel("Name of Rows", size=8, weight="bold")
plt.title("Missing values in column", fontweight="bold", fontsize=12)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Data is given by leading financial services company that that assists customers in finding and applying for various banking and credit products.
#
#
# In the given data there are 58016 rows and 28 columns. Data types mostly int,float and object.It does not contain any duplicate and null values.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#                  ID   Customer_ID         Month           Age           SSN  \
# count  10288.000000  10288.000000  10288.000000  10288.000000  1.028800e+04
# mean   13347.500000  26059.739502      4.500000     33.374417  4.934782e+08
# std     4455.050442  14570.909077      2.291399     10.759582  2.908478e+08
# min     5634.000000   1030.000000      1.000000     14.000000  8.661820e+05
# 25%     9489.750000  13654.000000      2.750000     25.000000  2.403635e+08
# 50%    13347.500000  25823.500000      4.500000     33.000000  4.728624e+08
# 75%    17205.250000  39299.000000      6.250000     42.000000  7.511875e+08
# max    21061.000000  50984.000000      8.000000     56.000000  9.998496e+08
#
#        Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count   10288.000000           10288.000000       10288.000000
# mean    51925.949918            4316.316145           5.332912
# std     38630.751670            3209.334946           2.642843
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# ##Categorical Columns:-
#
# 1.Customer_ID
#
# 2.Month
#
# 3.Name
#
# 4.SSN
#
# 5.Occupation
#
# 6.Num_Bank_Accounts
#
# 7.Num_Credit_Card
#
# 8.Num_of_Loan
#
# 9.Type_of_Loan
#
# 10.Credit_Mix
#
# 11.Payment_of_Min_Amount
#
# 12.Payment_Behaviour
#
# 13.Credit_Score
#
#
# ##Numerical Columns:-
#
# 14.Age
#
# 15.Annual_Income
#
# 16.Monthly_Inhand_Salary
#
# 17.Interest_Rate
#
# 18.Delay_from_due_date
#
# 19.Num_of_Delayed_Payment
#
# 20.Changed_Credit_Limit
#
# 21.Num_Credit_Inquiries
#
# 22.Outstanding_Debt
#
# 23.Credit_Utilization_Ratio
#
# 24.Credit_History_Age
#
# 25.Total_EMI_per_month
#
# 26.Amount_invested_monthly
#
# 27.Monthly_Balance

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()
# Out:
# ID                          10288
# Customer_ID                  1286
# Month                           8
# Name                         1259
# Age                            43
# SSN                          1286
# Occupation                     15
# Annual_Income                1286
# Monthly_Inhand_Salary        1350
# Num_Bank_Accounts              11
# Num_Credit_Card                12
# Interest_Rate                  34
# Num_of_Loan                    10
# Type_of_Loan                  827
# Delay_from_due_date            63
# Num_of_Delayed_Payment         26
# Changed_Credit_Limit         1772
# Num_Credit_Inquiries           18
# Credit_Mix                      4
# Outstanding_Debt             1284
# Credit_Utilization_Ratio    10287
# Credit_History_Age            404
# Payment_of_Min_Amount           3
# Total_EMI_per_month          1200
# Amount_invested_monthly      1268
# Payment_Behaviour               6
# Monthly_Balance             10108
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
def reverse_age(age):
    try:
        # Convert to integer safely (remove decimals)
        age = int(float(age))

        # Reverse only if age < 18
        if age < 18:
            return int(str(age)[::-1])
        return age

    except:
        return age  # return as-is if conversion fails
df["Age"] = df["Age"].apply(reverse_age)


print(df)
# Out:
#           ID  Customer_ID  Month            Name  Age          SSN Occupation  \
# 0       5634         3392      1   Aaron Maashoh   23  821000265.0  Scientist
# 1       5635         3392      2   Aaron Maashoh   23  821000265.0  Scientist
# 2       5636         3392      3   Aaron Maashoh   23  821000265.0  Scientist
# 3       5637         3392      4   Aaron Maashoh   23  821000265.0  Scientist
# 4       5638         3392      5   Aaron Maashoh   23  821000265.0  Scientist
# ...      ...          ...    ...             ...  ...          ...        ...
# 10283  21057        10476      4  Michael Roddyt   33  901014028.0   Musician
# 10284  21058        10476      5  Michael Roddyt   33  901014028.0   Musician
# 10285  21059        10476      6  Michael Roddyt   33  901014028.0   Musician
# 10286  21060        10476      7  Michael Roddyt   33  901014028.0   Musician
# 10287  21061        10476      8  Michael Roddyt   33  901014028.0   Musician
#
# ...

# %%
#Removing NM and replace wtih Not mentioned
df['Payment_of_Min_Amount'] = df['Payment_of_Min_Amount'].replace({'NM': "Not Mentioned"})       #replace NM to not mentioned
df.loc[:,'Payment_of_Min_Amount'].value_counts().reset_index()
# Out:
#   Payment_of_Min_Amount  count
# 0                   Yes   5387
# 1                    No   3647
# 2         Not Mentioned   1253

# %%
#Due to multiple entry of person filtring the data so that get the clean for practical benefit
#reduces random fluctuations, and gives a stable, representative value for analysis and modeling.
df= (df.sort_values(['Customer_ID', 'Month']).groupby('Customer_ID').agg({'Name': 'first','Age': 'first','Occupation': 'first','Annual_Income': 'first',
          'Monthly_Inhand_Salary' : 'first','Num_Bank_Accounts' : 'first',
          'Num_Credit_Card' : 'first','Interest_Rate' : 'first',
          'Num_of_Loan' : 'first','Type_of_Loan' : 'first',
          'Delay_from_due_date' : 'mean','Num_of_Delayed_Payment' : 'mean',
          'Changed_Credit_Limit' : 'mean','Num_Credit_Inquiries' : 'first', 'Credit_Mix':'first',
          'Outstanding_Debt' : 'mean','Credit_Utilization_Ratio': 'mean',
          'Credit_History_Age': 'max',
          'Payment_of_Min_Amount' : 'first','Total_EMI_per_month' :'first','Amount_invested_monthly':'first',
          'Monthly_Balance': 'mean','Credit_Score': 'last'}).reset_index())
print(df)
# Out:
#       Customer_ID            Name  Age    Occupation  Annual_Income  \
# 0            1030     Robert-Jano   33     Architect      122942.28
# 1            1039            Kohk   35  Entrepreneur       72588.99
# 2            1061  Hossein Jasebg   45        Lawyer       60572.70
# 3            1103   Nate Raymondr   34    Journalist       29369.12
# 4            1133          Luciaj   33      Musician       17770.48
# ...           ...             ...  ...           ...            ...
# 1281        50819      Tim Kellyh   26        Writer       36901.31
# 1282        50875        Kristend   20        Lawyer       60889.08
# 1283        50904       Fletcherb   33     Developer      120955.92
# 1284        50979    Soyoung Kimt   32      Mechanic       33386.25
# 1285        50984       Victoriah   20      Mechanic       19267.17
#
#       Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0              10205.190000                2.0              3.0
# ...

# %%
# Rounding Numbers into two decimal which making analysis and model results cleaner and more stable.
df['Monthly_Inhand_Salary'] =df['Monthly_Inhand_Salary'].round(2)
df['Annual_Income'] =df['Annual_Income'].round(2)
df['Total_EMI_per_month'] =df['Total_EMI_per_month'].round(2)
df['Amount_invested_monthly'] =df['Amount_invested_monthly'].round(2)
df['Monthly_Balance']=df['Monthly_Balance'].round(2)
df.loc[:,['Monthly_Inhand_Salary', 'Annual_Income', 'Total_EMI_per_month', 'Amount_invested_monthly', 'Monthly_Balance']]
# Out:
#       Monthly_Inhand_Salary  Annual_Income  Total_EMI_per_month  \
# 0                  10205.19      122942.28               101.57
# 1                   6242.08       72588.99                72.93
# 2                   4844.73       60572.70                88.72
# 3                   2171.43       29369.12                43.94
# 4                   1771.87       17770.48                19.47
# ...                     ...            ...                  ...
# 1281                2952.11       36901.31                27.97
# 1282                4859.09       60889.08               336.84
# 1283               10021.66      120955.92                57.51
# 1284                2851.19       33386.25                77.55
# 1285                1531.60       19267.17                77.63
#
#       Amount_invested_monthly  Monthly_Balance
# 0                      116.26           716.27
# 1                       42.32           591.50
# 2                       56.20           466.93
# ...

# %%
df.columns
# Out:
# Index(['Customer_ID', 'Name', 'Age', 'Occupation', 'Annual_Income',
#        'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card',
#        'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan', 'Delay_from_due_date',
#        'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Monthly_Balance', 'Credit_Score'],
#       dtype='object')

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# **What Data Manipulations Were Done?**
#
#
# 1. **Create a reverse function for age** so that we can convert age which is less than 18 because it may be typing error Example - In data age is 14 which is not eligible for loan. So We reverse it.
#
# 2. **Remove NM** from Payment_of_Min_Amount to Not Mentioned.
#
# 3. **Round Numerical Columns** - Round numerical columns upto two decimal for clean analysis.
#
# 4. **Create a new set of Data** - Due to multiple entry of person,filtring the data so that get the clean for practical benefit.Keep the first record of Name,Occupation,Annual Income,Monthly Salary, Number of bank account,Number of Credit Card, Interest Rate,Number of loan,Type of loan etc becuse they have the same value of per person, rest use mean for  summarizes a customer’s typical behavior across months, reduces random fluctuations, and gives a stable, representative value for analysis and modeling.

# %% [markdown]
# **What Insights Were Found?**
#
# 1-Annual Income - Customer have different level of income which is from 50000 to 200000 dollar. If we check skewnees it will be slightly right skewed. but We can not consider them as outliers because there is not such number which is out of the range.
#
# 2-In mininum payment some customer is shows as nm which is look like not mentioned.
#
# 3-Due to typing mistake age number look like miss typed (in age there are few customer's age is 14 which should be 41)
#
# 4-Customers with a longer credit history tend to maintain better credit scores.
#
# 5-Some customers have zero emi while some customers have higher income but low emi and some have high emi with low income.
#
# 5-Higher annual income is linked to better monthly balance, but income alone does not guarantee a good credit score.
#
# 6-More delayed payments directly increase outstanding debt and negatively affect credit scores.
#
# 7-Customers paying the minimum amount regularly are more likely to fall into poor or standard credit categories.
#
# 8-High number of loans and credit inquiries increases financial risk and lowers creditworthiness.
#
# 9-Standard credit score group forms the largest customer segment, indicating scope for improvement programs.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %% [markdown]
# Does the average annual income differ across different credit score categories?

# %%
# Chart - 1 visualization code
df_annual = df.groupby('Credit_Score')['Annual_Income'].mean().reset_index()
plt.figure(figsize=(6,3))
sns.barplot(x='Credit_Score', y='Annual_Income', color ='pink',data=df_annual)
plt.title('Average Annual Income by Credit Score')
plt.xlabel('Credit Score')
plt.ylabel('Average Annual Income')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar chart shows the clear comparision between average annual and credit score.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Customer with **good credit scores have highest average income**, while poor credit score customer earn the least.
#
# It's important to have a positive relationship between income level and with good credit score.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. This insights is very helpful to the business to understand customer risk better, approve loans more safely, and offer the right product's to the right customer's, which reduces losses and improves overall business decisions.
#
# And it will also help to strengthen the relationships between bank and customer.

# %% [markdown]
# #### Chart - 2

# %% [markdown]
# “How many credit cards do customers have across different credit score categories?”

# %%
# Chart - 2 visualization code
df_card = df.groupby('Credit_Score')['Num_Credit_Card'].mean().reset_index()
plt.figure(figsize=(6,3))
sns.barplot(x='Credit_Score', y='Num_Credit_Card',color = 'pink', data=df_card)
plt.title('Average Number of Credit Cards by Credit Score')
plt.xlabel('Credit Score')
plt.ylabel('Average Number of Credit Cards')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar chart shows the clear comparision between credit score and number of credit card

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Customers with poor credit score hold the highest number of credit cards,
#
# while those with a good credit score have fewer cards, suggesting better credit control and responsible usage among high-score customers.
#
# And standard score customer stand in between.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This will help the paisabazaar to identify risky customers who have many credit card and highest outstanding debt indicate higher default risk.
#
# This improves loan approval accuracy, reduces defaults, and increases profitability.

# %% [markdown]
# #### Chart - 3

# %% [markdown]
# How does the average credit utilization ratio differ by credit score?

# %%
# Chart - 3 visualization code
df_credit = df.groupby('Credit_Score')['Credit_Utilization_Ratio'].mean().reset_index()
plt.figure(figsize=(6,3))
sns.barplot(x='Credit_Score', y='Credit_Utilization_Ratio',color = 'pink', data=df_credit )
plt.title('Average Credit Utilization Ratio by Credit Score')
plt.xlabel('Credit Score')
plt.ylabel('Average Credit Utilization Ratio')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar chart shows the clear comparision credit utilization ratio and the credit score in a simple and easy to understand way.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Credit utilization ratio is very similar across all the credit score categories that utilization alone does not strongly differentiate good, standard and poor credit scores.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Credit utilization ration is similar accross all the credit score category which may lead to wrong credit decisions, increasing default risk if other factor are ignored.

# %% [markdown]
# #### Chart - 4
# What is the average number of delayed payments for each credit score category?

# %%
# Chart - 4 visualization code
df_delay = df.groupby('Credit_Score')['Num_of_Delayed_Payment'].mean().reset_index()
plt.figure(figsize=(6,3))
sns.barplot(x='Credit_Score', y='Num_of_Delayed_Payment',color = 'pink', data=df_delay)
plt.title('Average Number of Delayed Payments by Credit Score')
plt.xlabel('Credit Score')
plt.ylabel('Average Number of Delayed Payments')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Credit score clearly compaired with average number of delayed payment by bar chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Customer with poor credit score have maxinum number of delayed payment while good score customer have less number of delayed payment. On the other hand standard credit score customer are also high but less with poor credit score.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It clearly shows that payment delays strongly lower credit scores, helping the business focus on customers with high delay risk and reduce loan defaults.

# %% [markdown]
# #### Chart - 5
# Relationship between annual income and credit utilization ratio.

# %%
# Chart - 5 visualization code
plt.figure(figsize=(6,3))
sns.scatterplot(x='Annual_Income', y='Credit_Utilization_Ratio',color = 'pink', data=df)
plt.title('Annual Income vs Credit Utilization Ratio')
plt.xlabel('Annual Income of Customer')
plt.ylabel('Credit Utilization Ratio')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is used because it clearly shows the relationship between annual income and credit utilization ratio.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Annual income and credit utilization ratio shows a slight positive correlation. As income increases the maximun credit utilization ratio tend to rise, thought data remains densely clustered.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This insight helps the business understand that higher income customer useage credit utilization. Before taking any decision we should also look into others factors as well.

# %% [markdown]
# #### Chart - 6
# How is credit utilization ratio distributed across the dataset?

# %%
# Chart - 6 visualization code
plt.figure(figsize=(6,3))
sns.histplot(df['Credit_Utilization_Ratio'],color = 'pink', bins=8, kde=True)
plt.title('Distribution of Credit Utilization Ratio')
plt.xlabel('Credit Utilization Ratio')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Histogram shows the distribution and spread of credit utilization ratio.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Credit utilization is mostly concentrated around the mid range, with few very low or very high values, showing that most customers use a moderate portion of their credit limit.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This insight showing that most of customers maintain moderate credit usage. This will also help to set realistic credit limits and target risky high - utilization customers early.

# %% [markdown]
# #### Chart - 7
# How does average outstanding debt vary across credit score groups?

# %%
# Chart - 7 visualization code
df_debt = df.groupby('Credit_Score')['Outstanding_Debt'].mean().reset_index()
plt.figure(figsize=(6,3))
sns.barplot(x='Credit_Score', y='Outstanding_Debt',color = 'pink', data=df_debt)
plt.title('Average Outstanding Debt by Credit Score')
plt.xlabel('Credit Score')
plt.ylabel('Average Outstanding Debt')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Horizontal bar chart show the comprasion between credit socre and the average outstanding debt.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Customers with poor credit score have high outstanding debt,while good credit socre customers have low outstanding debt.Standard credit score customers have more than average outstanding debt compare to good credit score but less than poor credit score customers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It shows that customers with poor credit scores carry the highest outstanding debt, helping the business identify high-risk customers and tighten credit policies to reduce defaults.

# %% [markdown]
# #### Chart - 8
# How does the number of loans taken vary across credit score categories?

# %%
# Chart - 8 visualization code
df_loan = df.groupby('Credit_Score')['Num_of_Loan'].mean().reset_index()
plt.figure(figsize=(6,3))
sns.barplot(x='Credit_Score', y='Num_of_Loan',color = 'pink', data=df_loan)
plt.title('Average Number of Loans by Credit Score')
plt.xlabel('Credit Score')
plt.ylabel('Average Number of Loans')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar chart shows the comprasion between credit score and average number of loan taken by customers

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Customers with poor credit scores have the highest average number of loans, while those with good credit scores have the fewest, indicating that taking more loans is associated with poor credit score.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This will help the business that poor credit score customers have higher number of average loan which may defaults. So it will help to set safer loan limits which reduce the defaults and supports better lending decisions.

# %% [markdown]
# #### Chart - 9
# Credit Utilization ratio releate to credit score.

# %%
# Chart - 9 visualization code
plt.figure(figsize=(6,3))
sns.scatterplot(x='Num_of_Delayed_Payment', y='Outstanding_Debt',color = 'pink', data=df)
plt.title('Number of Delayed Payments vs Outstanding Debt')
plt.xlabel('Number of Delayed Payments')
plt.ylabel('Outstanding Debt')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Scatter Plot is choosen because it shows the relationship between number of delayed payments and outstanding debts.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It shows the positive relationship between the number of delayed payment and outstanding debt. As number of delayed payment increases, outstanding debt also increases, indicating that frequent payment delays are linked to higher debt and greater finincal risk.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This help the business to identify the customers who delayed payment more and try to reduce the reduce the debt and risk of defaults. If business ingore the delayed payment customers it will rise the risk of rising debt and customers defaults and financial losses.

# %% [markdown]
# #### Chart - 10
# How does total emi per month relate to the monthly balance?

# %%
# Chart - 10 visualization code
plt.figure(figsize=(6,3))
sns.scatterplot(x='Total_EMI_per_month', y='Monthly_Balance',color = 'pink', data=df)
plt.title('Total EMI per Month vs Monthly Balance')
plt.xlabel('Total EMI per Month')
plt.ylabel('Monthly Balance')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Scatter plot show the neat comprasion between total emi per month and monthly balance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is a negative relationship between total emi per month and monthly balance. As total emi increases, the balance generally decreases, indicating higher loan obligation reduce customer available monthly fund and increase financial stess.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It helps the business identify customers with high EMI burden and low remaining balance, allowing safer loan approvals and better risk control.

# %% [markdown]
# #### Chart - 11
# Percentage distribution of credit score categories.

# %%
# Chart - 11 visualization code
plt.figure(figsize=(6,3))  # Set the figure size
plt.pie(df['Credit_Score'].value_counts(), labels=df['Credit_Score'].value_counts().index,shadow='True', autopct='%1.1f%%')
plt.title('Percentage Distribution of Credit Score Categories')
plt.legend()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It clearly shows the distribtion of credit score.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Larger number of credit score is standard with 52.5% showing an average credit profile while customer with good credit socre are only 19.1% ,meaning fewer customers are financially strong and customers with poor credit score stand with 28.4% between standard and good, which indicates higher credit risk.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This will help us on which segament we have to focus, how can we reduce our credit risk and increase profitability through better lending.

# %% [markdown]
# #### Chart - 12
# How is credit history age distributed among customers?

# %%
# Chart - 12 visualization code
plt.figure(figsize=(6,3))
plt.hist(df['Credit_History_Age'], color = 'pink' , bins=8)
plt.title('Distribution of Credit History Age')
plt.xlabel('Credit History Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Histogram shows the clear distribution of credit history age.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most of customers have a medium to long credit history, with fewer customers having very short histories.This shows the dataset is dominated by experienced borrowers, which usually indicates more stable and reliable credit behavior.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. These insights help businesses assess customer risk more accurately, design better credit products, improve approval decisions, reduce defaults, and focus offers on reliable customers, leading to higher profitability and better customer satisfaction.

# %% [markdown]
# #### Chart - 13
# How are customers distributed by payment of minimum amount (Yes/No)?

# %%
# Chart - 13 visualization code
# Filter out 'Not Mentioned' entries before plotting
filtered_df = df[df['Payment_of_Min_Amount'] != 'Not Mentioned']
plt.figure(figsize=(6,3))
sns.countplot(x='Payment_of_Min_Amount', data=filtered_df ,hue = 'Credit_Score')
plt.title('Distribution of Payment of Minimum Amount')
plt.xlabel('Payment of Minimum Amount')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Count plot shows how payment of mininum amount is clearly distributed.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Customer with good credit socre have paid the minimum amount on time showing better financial discipline.Poor credit score customers more offten miss or skip minimum payment,increasing default risk.Standard customers fall in between.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# These insights help identify high-risk customers early, improve credit policies, design better repayment reminders, and offer targeted financial products—reducing defaults, improving customer trust, and increasing overall business profitability.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Drop non-numerical / ID columns
df_corr = df.drop(columns=['Customer_ID', 'Age'], errors='ignore')

# Select numerical columns
num_cols = df_corr.select_dtypes(include='number')

# Plot heatmap
plt.figure(figsize=(20,15))
sns.heatmap(
    num_cols.corr(),
    annot=True,
    fmt=".2f",
    cmap='coolwarm',
    linewidths=0.5
)

plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heatmap shows correlation between numeric variables clearly,helping identify relationship in one visual view.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# High income and long credit history support financial health, while excessive borrowing, high utilization, and payment delays increase credit risk. This helps businesses identify low-risk customers and prevent negative growth by controlling high-risk lending.

# %% [markdown]
# #### Chart - 15 - Pair Plot
# Annual Income Vs Credit Score

# %%
# Pair Plot visualization code
plt.figure(figsize=(20,15))
cols = ['Annual_Income','Credit_Utilization_Ratio', 'Outstanding_Debt','Monthly_Balance','Num_of_Loan', 'Num_of_Delayed_Payment']
sns.pairplot(df.sample(300), vars=cols, hue='Credit_Score',height=3,diag_kind='kde')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pair plot helps to compare multiple financial features simultaneously and understand how their relationships vary across the different credit score categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Customers with higher income and lower credit utilization moslty have good credit scores.
#
# - Poor credit scores are linked with higher outstanding debt and more delayed payments.
#
# - As the numbers of loan and late payment increas, credit score quality generally declines.
#
# - Standard credit score customers fall in between good and poor, showing mixed behavior.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Suggestions to achieve the Buiness Objective
#
# To meet the goal of improving better risk management, reduce defaults risk , reduce credit utilization and better financial management the following actions are recommended:
#
# 1-Segment customers based on credit score, risk level, and repayment behavior to enable better decision-making.
#
# 2-Use credit utilization ratio, delayed payments, and outstanding debt as key factors for loan approval and interest rate pricing.
#
# 3-Offer personalized loan terms such as lower interest rates or higher limits to customers with good credit scores.
#
# 4-Identify high-risk customers early and apply preventive actions like payment reminders, credit counseling, or limit controls.
#
# 5-Encourage customers to reduce credit utilization and pay dues on time through awareness programs and incentives.
#
# 6-Focus on improving standard credit score customers, as they form the largest group and can be upgraded to good credit status.
#
# 7- Optimize EMI structures so customers can maintain healthy monthly balances.
#
# 8-Monitor customer behavior regularly using dashboards to track changes in credit risk over time.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This project analyzed customer credit data to understand the key factors that influence credit scores. By studying income, credit utilization, loans, delayed payments, outstanding debt, and credit history, the analysis revealed clear patterns in customer credit behavior. Customers with good credit scores generally manage their credit well, have fewer payment delays, and maintain balanced debt levels, while poor credit score customers show higher financial risk. The study also showed that repayment behavior and credit utilization have a stronger impact on credit scores than income alone. These insights can help financial institutions improve credit assessment, reduce default risk, and design more personalized financial products, leading to better business decisions and long-term growth.
#
# Based on insights,it is recommended that PaizaBazaar:
#
# 1-Credit utilization ratio and payment delays are major drivers of credit score.
#
# 2-Higher income supports financial stability but does not guarantee a good credit score.
#
# 3-Customers with longer credit history tend to have better credit scores.
#
# 4-High outstanding debt and EMI burden increase credit risk.
#
# 5-Standard credit score customers present an opportunity for improvement programs.
#
# 6-Insights support better loan approvals, risk management, and customer targeting.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
